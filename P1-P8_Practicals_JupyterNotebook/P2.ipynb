# %% [markdown]
# # Practical 2

# %% [markdown]
# ### 1. Insert Element in Array

# %% [markdown]
# **Question:** Write a program to insert an element at a given position in an array.

# %%
arr = list(map(int, input("Enter elements: ").split()))
pos = int(input("Position: "))
val = int(input("Value: "))
arr.insert(pos - 1, val)
print(arr)
# Out:
# [9, 222]

# %% [markdown]
# ### 2. Access Matrix Recursively

# %% [markdown]
# **Question:** Write a program to display a matrix using recursion.

# %%
def show(a, i, j):
    if i == len(a):
        return
    print(a[i][j], end=" ")
    if j == len(a[0]) - 1:
        print()
        show(a, i + 1, 0)
    else:
        show(a, i, j + 1)

r, c = map(int, input().split())
a = [list(map(int, input().split())) for _ in range(r)]
show(a, 0, 0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 11
#       7         show(a, i + 1, 0)
#       8     else:
#       9         show(a, i, j + 1)
#      10
# ---> 11 r, c = map(int, input().split())
#      12 a = [list(map(int, input().split())) for _ in range(r)]
#      13 show(a, 0, 0)
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %% [markdown]
# ### 3. Matrix Addition and Multiplication

# %% [markdown]
# **Question:** Write a program to perform addition and multiplication of two matrices.

# %%
r, c = map(int, input().split())
A = [list(map(int, input().split())) for _ in range(r)]
B = [list(map(int, input().split())) for _ in range(r)]

print("Addition")
for i in range(r):
    row = []
    for j in range(c):
        row.append(A[i][j] + B[i][j])
    print(row)

print("Multiplication")
for i in range(r):
    row = []
    for j in range(c):
        s = 0
        for k in range(c):
            s += A[i][k] * B[k][j]
        row.append(s)
    print(row)

# %% [markdown]
# ### 4. Transpose Matrix

# %% [markdown]
# **Question:** Write a program to find the transpose of a matrix.

# %%
r, c = map(int, input().split())
a = [list(map(int, input().split())) for _ in range(r)]
for j in range(c):
    for i in range(r):
        print(a[i][j], end=" ")
    print()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 r, c = map(int, input().split())
#       2 a = [list(map(int, input().split())) for _ in range(r)]
#       3 for j in range(c):
#       4     for i in range(r):
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %% [markdown]
# ### 5. Stack Using List

# %% [markdown]
# **Question:** Write a program to implement a stack using a list (LIFO).

# %%
stack = []
stack.append(10)
stack.append(20)
print(stack)
print("Pop:", stack.pop())
print(stack)

# %% [markdown]
# **Sample Output:**
# ```
# [10, 20]
# Pop: 20
# [10]
# ```

# %% [markdown]
# ### 6. Linked List Insertion

# %% [markdown]
# **Question:** Write a program to create a linked list and insert/display elements.

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

head = Node(10)
head.next = Node(20)
head.next.next = Node(30)
temp = head
while temp:
    print(temp.data, end=" ")
    temp = temp.next

# %% [markdown]
# **Sample Output:**
# ```
# 10 20 30
# ```
